# %% [markdown]
# # Data Description

# %% [markdown]
# Problem Statement:
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# Attribute Information
#
# Given is the attribute name, attribute type, the measurement unit and a brief description. The number of rings is the value to predict.
#
# Name / Data Type / Measurement Unit / Description
# -----------------------------
# Sex / nominal / -- / M, F, and I (infant)
# Length / continuous / mm / Longest shell measurement
# Diameter / continuous / mm / perpendicular to length
# Height / continuous / mm / with meat in shell
# Whole weight / continuous / grams / whole abalone
# Shucked weight / continuous / grams / weight of meat
# Viscera weight / continuous / grams / gut weight (after bleeding)
# Shell weight / continuous / grams / after being dried
# Rings / integer / -- / +1.5 gives the age in years.
#
# You have to predict the rings of each abalone which will lead us to the age of that abalone.

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import warnings
warnings.filterwarnings('ignore')

from pandas_profiling import ProfileReport

# %% [markdown]
# # Loading the Dataset

# %%
df= pd.read_csv("abalone.csv")

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# We have a clean dataset with 4177 samples(rows) and 9 attributes(columns).
# No Null values. Hence, no need for filling any missing Nan values.
# All attributes in Float datatype with the exception of Gender attribute(Categorical) and Rings(Target Variable) being an Integer datatype.

# %%
profile= ProfileReport(df)
profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# We see a high correlation between the independent variables.

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# We see that most values are between 0 and 1. Hence, we will not be using Scaling for this dataset.
# The standard deviation of the dataset is below 1 indicating that the data is not highly dispersed.
# The mean and median values are also in the same range.

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole_weight      float64
# Shucked_weight    float64
# Viscera_weight    float64
# Shell_weight      float64
# Rings               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Re-confirming that there are no null values in the dataset.

# %%
sns.distplot(df['Rings'])
plt.show()

# %% [markdown]
# We see a spike in the frequency distribution for Rings indicating most of the Ring values concentrated between 5-15 numbers.

# %%
sns.pairplot(df,hue='Sex',diag_kind='kde')
plt.show()

# %% [markdown]
# In the pairplot with Sex as hue, all features is having a similar distribution for both male and female, but the distribution of infants is different from distribution of male and female. All attributes are having high correlation and multicollinearity with each other.

# %% [markdown]
# Further let's examine correlation using a heatmap.

# %%
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# There is positive correlation of all variables with target variable. Shell_weight has highest at 0.63 and Shucked_weight lowest at 0.42.

# %% [markdown]
# Due to string values, Sex variable is not reflecting in this heatmap. We need to label encode it first.

# %%
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
df["Sex"]=LE.fit_transform(df["Sex"])

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# # Data distribution among all the columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), legend=False, sharex=False, fontsize=1, figsize=(18,12)) 
plt.show()

# %% [markdown]
# # Checking Outliers

# %%
df.boxplot(figsize=[10,20])

# %% [markdown]
# We can see most outlier values near whisker which could be ignored. However, the Height and Rings have a significant presence of outliers.

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
print(z)
z.shape
# Out:
# [[1.15198011 0.57455813 0.43214879 ... 0.72621157 0.63821689 1.57154357]
#  [1.15198011 1.44898585 1.439929   ... 1.20522124 1.21298732 0.91001299]
#  [1.28068972 0.05003309 0.12213032 ... 0.35668983 0.20713907 0.28962385]
#  ...
#  [1.15198011 0.6329849  0.67640943 ... 0.97541324 0.49695471 0.28962385]
#  [1.28068972 0.84118198 0.77718745 ... 0.73362741 0.41073914 0.02057072]
#  [1.15198011 1.54905203 1.48263359 ... 1.78744868 1.84048058 0.64095986]]
# (4177, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
df= df[(z < 3).all(axis=1)]

# %%
df.shape
# Out:
# (4027, 9)

# %% [markdown]
# Outliers have now been removed from data. We have 4027 rows post that. Let us now look for any skewness present in the data.

# %%
df.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole_weight      0.334204
# Shucked_weight    0.458295
# Viscera_weight    0.437116
# Shell_weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# We can observe the skewness in the data has decreased. Most values are well within the threshold of +-0.5

# %%
x=df.drop("Rings",axis=1)
y=df["Rings"]

# %% [markdown]
# # Finding best random_state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
minErr=0
maxRS=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.30, random_state=i)
    LR= LinearRegression()
    LR.fit(x_train,y_train)
    predrf = LR.predict(x_test)
    mse= mean_squared_error(y_test, predrf)
    if mse>minErr:
        minErr=mse
        maxRS=i
print("Least error is",minErr, "on Random_State ", maxRS)
# Out:
# Least error is 4.805539733101434 on Random_State  346

# %% [markdown]
# We have best random state as 346.

# %% [markdown]
# # Model

# %%
x_train,x_test, y_train,y_test= train_test_split(x,y,test_size=0.30, random_state=346)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

LR= LinearRegression()
LR.fit(x_train,y_train)
predlr= LR.predict(x_test)
print("MSE is:",mean_squared_error(y_test,predlr))
print("R2 score is:",r2_score(y_test,predlr))
# Out:
# MSE is: 4.805539733101434
# R2 score is: 0.49301086661770344

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
RF.fit(x_train,y_train)
predrf= RF.predict(x_test)
print("MSE is:",mean_squared_error(y_test,predrf))
print("R2 score is:",r2_score(y_test,predrf))
# Out:
# MSE is: 4.737704383788256
# R2 score is: 0.5001675621963658

# %%
from sklearn.model_selection import GridSearchCV,KFold,cross_val_score
from sklearn.metrics import r2_score,mean_squared_error

folds = KFold(n_splits=5,shuffle=True,random_state=0)

# %%
cv1=cross_val_score(LR,x,y,cv=folds,scoring='neg_mean_squared_error')
cv1
# Out:
# array([-4.08751951, -4.35569293, -3.70037936, -4.24826529, -3.64997018])

# %%
print("RMSE of Linear Regression model: ",np.mean(cv1*-1)**0.5)
# Out:
# RMSE of Linear Regression model:  2.0020902706258425

# %%
cv2 = cross_val_score(RF,x,y,cv=folds,scoring='neg_mean_squared_error')
cv2
# Out:
# array([-3.99497804, -3.96863598, -3.39825503, -3.98281876, -3.34583677])

# %%
print("RMSE of RandomForest Regressor model: ",np.mean(cv2*-1)**0.5)
# Out:
# RMSE of RandomForest Regressor model:  1.933417936135761

# %% [markdown]
# We see that the RMSE of the RandomForest is performing the best. Let us save the model.

# %%
import joblib
joblib.dump(RF,"AbaloneModel.pkl")
# Out:
# ['AbaloneModel.pkl']
